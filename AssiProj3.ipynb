# %% [markdown]
# We will load our dataset into the Pandas dataframe

# %%
import pandas as pd

df_pd.read_csv('MOTOVEHICLE COLLISION.csv')

#Display the first few rows of the DataFrame to understand its structur
df.head()

# %% [markdown]
# Let us import all the neccessary libraries

# %%
import matplot;ib.pyplot as plt
import seaborn as sns

# %% [markdown]
# We will cfreate various plots/graphs for us to visually have a feel for the dataset

# %%
plt.hist(df['NUMBER OF PERSONS INJURED'], bins=20,colour='skyblue',edgecolour='black')
plt.xlabel('Number of Persons Injured')
plt.ylabel('Frequency')
plt.title('Distribution of Number of Persons Injured')
plt.show()

# %% [markdown]
# We will showcase the relation between number of persons injured and number of persons killed with a scatterplot

# %%
plt.scatter(df['NUMBER OF PERSONS INJURED'],df['NUMBER OF PERSONS KILLED'])
plt.xlabel('Number of Persons Injured')
plt.ylabel('Number of Persons Killed')
plt.title('Relaionship between people killed and people injured')
plt.show()

# %% [markdown]
# This will be a line chart to visually see a trend of the people injured over time

# %%
df['DATE OF CRASH']=pd.to_datetime(df['DATE OF CRASH'])#This will convert Date of crash column into datetime format
plt.plot(df['DATE OF CRASH'],df['NUMBER OF PERSONS INJURED'], marker='o', linestyle='-')
plt.xlabel('Date')
plt.ylabel('Number of Persons Injured')
plt.title('Trend of Persons Injured Over Time')
plt.xtricks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# Now we will test the correlation visually by using a heat map

# %%
correlation_matrix = df.corr()
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt".2f")
plt.title('Correlation Heatmap')
plt.show()
